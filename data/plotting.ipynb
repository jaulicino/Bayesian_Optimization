# %%
import numpy as np

scores = np.genfromtxt("round9_observed_scores_scalarized.txt")

# %%
scores
# Out:
# array([ 8.460506  , 44.03879724, 47.7523509 , 49.04847555, 43.90574196,
#        49.33730764, 45.90013372,  7.82531896, 49.42498776, 39.56498004,
#        42.86631021, 14.39977211, 45.78715979, 39.02232523, 51.26024976,
#        41.32529716, 41.54899095, 53.04329934, 48.63635502])

# %%
from matplotlib import pyplot as plt

plt.plot(range(len(scores)), scores)
plt.xlabel("Number of Points Sample (increases with more rounds)")
plt.ylabel("Scalarized Score")
plt.title("Score by Number of Points for the Final Scalarization")
# Out:
# Text(0.5, 1.0, 'Score by Number of Points for the Final Scalarization')
